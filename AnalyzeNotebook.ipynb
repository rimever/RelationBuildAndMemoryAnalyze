# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame([[54,40,45],[58,47,43],[61,46,43]],columns=['4GB','6GB','8GB'])

# %%
df.head
# Out:
# <bound method NDFrame.head of    4GB  6GB  8GB
# 0   54   40   45
# 1   58   47   43
# 2   61   46   43>

# %%
df.plot()
